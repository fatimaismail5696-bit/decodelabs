# %%
# ==============================
# TO-DO LIST MANAGEMENT SYSTEM
# ==============================

# Empty list to store tasks
tasks = []

# Infinite loop for menu
while True:

    print("\n===== TO-DO LIST MENU =====")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Complete Task")
    print("4. Delete Task")
    print("5. Exit")

    # User choice
    choice = input("Enter your choice: ")

    # =========================
    # ADD TASK
    # =========================
    if choice == "1":

        task_name = input("Enter task name: ")

        # Dictionary for one task
        task = {
            "name": task_name,
            "status": "Pending"
        }

        # Add dictionary into list
        tasks.append(task)

        print("Task added successfully!")

    # =========================
    # VIEW TASKS
    # =========================
    elif choice == "2":

        if len(tasks) == 0:
            print("No tasks available.")

        else:
            print("\nYour Tasks:")

            # Loop through list
            for index, task in enumerate(tasks, start=1):

                print(f"{index}. {task['name']} - {task['status']}")

    # =========================
    # COMPLETE TASK
    # =========================
    elif choice == "3":

        if len(tasks) == 0:
            print("No tasks available.")

        else:
            for index, task in enumerate(tasks, start=1):

                print(f"{index}. {task['name']} - {task['status']}")

            number = int(input("Enter task number to complete: "))

            if number >= 1 and number <= len(tasks):

                tasks[number - 1]["status"] = "Completed"

                print("Task marked as completed!")

            else:
                print("Invalid task number.")

    # =========================
    # DELETE TASK
    # =========================
    elif choice == "4":

        if len(tasks) == 0:
            print("No tasks available.")

        else:
            for index, task in enumerate(tasks, start=1):

                print(f"{index}. {task['name']}")

            number = int(input("Enter task number to delete: "))

            if number >= 1 and number <= len(tasks):

                deleted = tasks.pop(number - 1)

                print("Deleted task:", deleted["name"])

            else:
                print("Invalid task number.")

    # =========================
    # EXIT PROGRAM
    # =========================
    elif choice == "5":

        print("Exiting program...")
        break

    # =========================
    # INVALID INPUT
    # =========================
    else:

        print("Invalid choice. Try again.")
# Out:
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Enter your choice:  1
# Enter task name:  revision
# Task added successfully!
#
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Enter your choice:  1
# Enter task name:  gaming
# Task added successfully!
#
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Enter your choice:  2
# Your Tasks:
# 1. revision - Pending
# 2. gaming - Pending
#
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Enter your choice:  3
# 1. revision - Pending
# 2. gaming - Pending
# Enter task number to complete:  1
# Task marked as completed!
#
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Enter your choice:  2
# Your Tasks:
# 1. revision - Completed
# 2. gaming - Pending
#
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Enter your choice:  4
# 1. revision
# 2. gaming
# Enter task number to delete:  2
# Deleted task: gaming
#
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Enter your choice:  5
# Exiting program...
